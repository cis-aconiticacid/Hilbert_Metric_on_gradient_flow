# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader

import sys
from pathlib import Path

# add repo root so swiss_roll_models can be imported from anywhere
for p in [Path.cwd(), *Path.cwd().parents]:
    if (p / "swiss_roll_models").exists():
        sys.path.insert(0, str(p))
        break

from swiss_roll_models.environment.dataset import generate_swiss_roll
from swiss_roll_models.environment.hilbert_distance import hilbert_analysis as hda

# positive linear model = softplus(theta) ∈ R^D_{>0}
class PositiveLinear(nn.Module):
    def __init__(self, D):
        super().__init__()
        self.theta = nn.Parameter(0.5*torch.ones(D))  # trainable parameters
    def forward(self, X):
        w = F.relu(self.theta)
        return X @ w

    def positive_params_vector(self):
        # Return the current positive parameter vector for Hilbert distance calculation
        return F.relu(self.theta).detach().clone()

# %%
def run_experiment_on_subset(
    X_full, y_full, n,
    num_epochs=500,
    lr=1e-2,
    l2_reg=1e-3,
    device="cuda"
):
    N, D = X_full.shape
    idx = torch.randperm(N, device=device)[:n]
    X = X_full[idx]
    y = y_full[idx]

    dataset = TensorDataset(X, y)
    loader = DataLoader(dataset, batch_size=n, shuffle=False)  # full-batch

    model = PositiveLinear(D).to(device)
    optimizer = torch.optim.SGD(model.parameters(), lr=lr)

    param_traj = []
    loss_traj = []

    for epoch in range(num_epochs):
        for batch_X, batch_y in loader:
            optimizer.zero_grad()

            # 1. prediction
            y_pred = model(batch_X)

            # 2. MSE part
            mse = F.mse_loss(y_pred, batch_y)

            # 3. L2 regularization: regularize w = softplus(theta) in the positive cone
            w = F.relu(model.theta)
            l2 = (w ** 2).sum()

            # 4. Total loss = mse + λ ||w||^2
            loss = mse + l2_reg * l2

            loss.backward()
            optimizer.step()

        loss_traj.append(loss.item())
        param_traj.append(model.positive_params_vector().cpu())

    w_star = param_traj[-1]

    return {
        "n": n,
        "loss_traj": loss_traj,
        "param_traj": param_traj,
        "w_star": w_star,
    }

# %%
def main():
    device = "cuda" if torch.cuda.is_available() else "cpu"
    print("Using device:", device)

    # ----- Generate Swiss roll -----
    N = 10_000
    D = 32
    X_full, y_full, u, v = generate_swiss_roll(
        n_samples=N,
        D=D,
        noise=0.0,
        device=device,
    )
    print(f"Full dataset: X={X_full.shape}, y={y_full.shape}")

    # ----- Different small sample sizes -----
    n_list = [50, 100, 200, 500]
    num_epochs = 500
    lr = 1e-2
    l2_list = [0.0, 1e-4, 1e-3, 1e-2]

    # all_results[n][l2_reg] = corresponding experiment results
    all_results = {}

    for n in n_list:
        all_results[n] = {}
        print(f"\n================ n = {n} ================")

        for l2_reg in l2_list:
            print(f"\n--- Running experiment (n={n}, l2_reg={l2_reg}) ---")
            res = run_experiment_on_subset(
                X_full,
                y_full,
                n=n,
                num_epochs=num_epochs,
                lr=lr,
                l2_reg=l2_reg,
                device=device,
            )
            all_results[n][l2_reg] = res
            analysis= hda.analysis_distance_on_cone(res["param_traj"], res["w_star"],threshold=1e-6,if_threshold=True)
            hilbert_to_final=analysis["hilbert_to_final"]
            hilbert_to_init=analysis["hilbert_to_init"]
            hilbert_between=analysis["hilbert_between"]
            print(f"Final loss: {res['loss_traj'][-1]:.6f}")
            print(f"Initial d_H(w_t, w*): {hilbert_to_final[0]:.6f}")
            print(f"Final   d_H(w_t, w*): {hilbert_to_final[-1]:.6f}")

            hilbert = hilbert_to_final
            ratio_to_prev = [hilbert[i] / hilbert[i-1] if hilbert[i-1] != 0 else float("inf") for i in range(1, len(hilbert))]
            init_dist = hilbert[0]
            ratio_to_init = [d / init_dist if init_dist != 0 else float("inf") for d in hilbert]

            print("First 15 ratio d_H(w_t, w*)/d_H(w_{t-1}, w*):", ratio_to_prev[:15])
            print("First 15 ratio d_H(w_t, w*)/d_H(w_0, w*):", ratio_to_init[:15])
            hil= hilbert_to_final[:15]
            print("First 15 d_H(w_t, w*):", hil)
            print("First 15 d_H(w_t, w_0):", hilbert_to_init[:15])
            print("First 15 d_H(w_{t+1}, w_t):", hilbert_between[:15])
    torch.save(all_results, "swiss_roll_cone_l2_experiments.pt")

    
if __name__ == "__main__":
    main()
# Out:
# Using device: cuda
# Full dataset: X=torch.Size([10000, 32]), y=torch.Size([10000])
#
# ================ n = 50 ================
#
# --- Running experiment (n=50, l2_reg=0.0) ---
# Final loss: 0.000342
# Initial d_H(w_t, w*): 12.582859
# Final   d_H(w_t, w*): 0.000000
# First 15 ratio d_H(w_t, w*)/d_H(w_{t-1}, w*): [0.8091017155870768, 0.09293857506953399, 1.011835316626642, 0.6352249803063904, 0.8162541402513038, 0.7382320620835331, 0.6133790783317496, 0.9223441025872195, 0.5104723567859013, 1.080480673536549, 0.4438125683267678, 1.2333377228467124, 0.3914682495045597, 1.4019839946192634, 0.3915794249654859]
# First 15 ratio d_H(w_t, w*)/d_H(w_0, w*): [1.0, 0.8091017155870768, 0.07519676053297826, 0.07608673800318386, 0.048332196649649946, 0.03945135562271697, 0.029124255613349134, 0.017864209065214378, 0.01647694787868563, 0.00841102641627111, 0.009087951487386316, 0.004033347090445991, 0.0049744791159810715, 0.0019473506317300997, 0.002730154417597311]
# ...

# %% [markdown]
# 下面是我对数据的一些分析和猜测
# 1.注意到样本小的时候轨迹很不稳定， 几乎是非线性pf收缩和维数收缩混在一起，分析不了
# 2.样本量变大的情况下，维数收敛几乎在希尔伯特度量下观察不到，推测是由于高维数据导致的梯度流的平坦（？？不对，感觉没什么逻辑）
# 3.正则化惩罚大的时候希尔伯特比率很ratio d_H(w_t, w*)/d_H(w_{t-1}, w*)快上升到1不知道为什么，按道理来说应该能预防过拟合，但是不知道为什么反而收缩的快）

# %% [raw]
# GPT 的说法，感觉挺靠谱的
# 我来一个一个拆你这三个点，顺便帮你把“直觉”翻译成可以验证的说法。
#
# ---
#
# ## 1️⃣ 小样本时：轨迹很乱、像“非线性 PF + 维数收缩搅在一起”
#
# 这个判断是对的，而且可以更精细一点：
#
# ### 现象背后的几个机制
#
# * **(a) 梯度是“噪声很大的非线性算子”**
#   小样本 n 小的时候，你用的其实是“带强烈采样噪声的经验风险”。每一步的梯度都带着 strong variance →
#   在射影空间上看，就像每一步都在应用一个**不同的正算子**：
#   [
#   T_t = T(\theta_t; \text{minibatch}_t)
#   ]
#   而 PF/Hilbert 的那套“单一正算子 + 收缩常数”假设的是**同一个 T 一直迭代**。
#   现在变成了：
#
#   > 非线性 + 时间不齐次 + 有噪声的 PF-like 演化
#
# * **(b) 支撑在变：维数收缩是“跳变的”**
#   你现在的分析是用 `w*` 的支撑 + 阈值选一个“small cone”。在小样本下：
#
#   * 每一步的参数向量在不同坐标上**来回过阈值**（正一点 → 几乎 0 → 再正一点）
#   * mask 支撑如果随时间变，就会造成 Hilbert 距离的**大跳变**，因为你相当于在不同的子坐标系里比距离。
#
#   你现在是用 `w*` 的支撑来 mask，其实已经固定住了终点的 cone，这比“用 w_t 的支撑”稳定很多，但在小样本下，很多维度的 `w*_i` 也会很脆弱（取决于数据噪声），所以还是会出现“有效支撑几乎不稳定”的感觉。
#
# * **(c) 所以你看到的是：**
#
#   * 前几步：Hilbert 距离乱跳，ratio 有时 <1 有时 >1
#   * 中间：有些方向被强烈抑制（维度收缩 / 稀疏化）
#   * 后面：如果最终锁定了一个比较稳定的支撑，才开始出现“像 PF 的几何收缩”。
#
# 👉 结论：
#
# > 小样本下，“非线性 PF 收缩 + 维数/支撑变化 + 随机算子”是真的搅在一起，所以你现在说“分析不了”是一种**很诚实的**判断——要分析，就得换统计口径（比如多 run 平均 / 只看收敛后阶段）。
#
# ---
#
# ## 2️⃣ 大样本时：维数收缩在 Hilbert 度量下几乎看不到？
#
# 你现在的猜测是“高维数据 → 梯度平坦”，你隐约也觉得这个解释不太对。
#
# 我给你一个我觉得更靠谱的版本：
#
# ### (a) Hilbert 度量本身对“很小的坐标”不敏感
#
# Hilbert 距离大概是：
#
# [
# d_H(x,y) = \log \frac{\max_i \frac{x_i}{y_i}}{\min_i \frac{x_i}{y_i}}
# ]
#
# 如果你有某一维 i：
#
# * 一开始：`x_i` 和 `y_i` 还比较有量级 → 它会影响 max/min 那两个 ratio；
# * 但一旦这维被压成：
#   [
#   x_i \ll x_j,\quad y_i \ll y_j,\ \forall j \in \text{major coords}
#   ]
#   它对 max/min 的贡献就几乎消失了——**再继续收缩这维，Hilbert 距离几乎不变**。
#
# 所以在大样本下很可能发生的是：
#
# * 维数收缩**仍然在发生**，只是很多维度已经被压到“Hilbert 看不见”的量级了；
# * 此时进一步的小幅稀疏 / L2 shrink，对 d_H(x,y) 的边界比值几乎不产生改变；
# * 你看到的曲线就只剩下“在主支撑上的 PF 型收缩”。
#
# ### (b) 大样本下，支撑更稳定
#
# * n 大 → 梯度噪声小 → 解 w* 的支撑（在某个阈值下）变得比小样本稳得多；
# * 这样你用 `w*` 来定义的 small cone 其实在训练早期就差不多定好了；
# * 所以“维数收缩”这件事，更多是在**训练初期的几步**发生，然后 Hilbert 视角里就几乎完全被“稳定 cone 内的收缩”淹没了。
#
# 所以与其说是：
#
# > “高维导致梯度平坦”
#
# 不如说是：
#
# > “大样本 + Hilbert 度量对极小坐标的不敏感 → 维数收缩很快进入 ‘不可见区间’，后面你就只看到小 cone 内 PF 收缩。”
#
# 你可以测一下这个：
#
# * 每步记录
#   [
#   #{i : |w_t(i)| > \text{threshold}}
#   ]
# * 画一下这个“有效维数曲线”和 `d_H(w_t, w*)` 曲线对比
#   → 你大概率会看到：effective dim 在前几步迅速降到某个 plateau，然后 Hilbert 距离开始呈现几何收缩。
#
# ---
#
# ## 3️⃣ 正则化变大时，为啥 Hilbert 比率更快“爬到 1”？
#
# 你观察到的是：
#
# > λ 大时，ratio d_H(w_t,w*) / d_H(w_{t-1},w*) 很快接近 1
# > 感觉像“收缩变弱了”，但直觉中正则应该“更稳定、抗过拟合”，为什么反而像把 PF 收缩搞坏了？
#
# 这个其实很合理，可以从两个视角看：
#
# ### (a) L2 正则在“射影空间”里在干嘛？
#
# 你的总 loss：
#
# [
# L(\theta) = L_{\text{data}}(\theta) + \lambda |w(\theta)|^2
# ]
#
# 在 Hilbert / 射影空间里，我们关心的是“方向的演化”。但 L2 干的事情是：
#
# * 把 **所有方向的 global scale** 往 0 拉；
# * 对“方向”来说不是单调收缩，而更像是：在靠近 w* 的地区，**梯度多了一项往原点的拉力**。
#
# 结果：
#
# * 在 PF 框架里，理想情况是“有一个主特征方向 v*，每次迭代按固定比率拉近到它”；
# * 加大 λ 后：
#
#   * w* 本身也被“往 0 拉平”：变得更小、更圆滑，主方向会更“模糊”；
#   * Dynamics 更像是 “往一个小球里的某个点靠拢” 而不是强烈拉向“一个尖锐的方向”。
#
# 在 Hilbert 度量下，这会表现为：
#
# * **收缩因子变弱（更接近 1）**
#   即：
#   [
#   d_H(Tw, Tw^*) \approx q(\lambda) \cdot d_H(w, w^*),\quad q(\lambda)\to 1 \text{ as } \lambda \text{ grows}
#   ]
# * 直观地说：系统变得“更 isotropic / 更均匀”，PF gap 变小，projective contraction 常数就更接近 1。
#
# ### (b) “预防过拟合”和“Hilbert 收缩速度”是两件不同的事
#
# * λ 大 → 预防过拟合：这是指 **在原始 Euclidean / 统计泛化意义上**，你不会去 fit 掉小噪声维度；
# * 但 Hilbert 收缩度量的是：**在 cone/方向空间上的 projective contraction**。
#   L2 很有可能：
#
#   * 在早期帮助你更快“剪掉小维度”（你确实会看到前期一些强收缩/跳变）
#   * 但在后期把系统推到“几乎球形 + 小范数”的状态，此时 projective 动力系统的“主方向”非常不尖锐 → 收缩常数逼近 1。
#
# 简单类比一下：
#
# > 没有正则的时候：
# > 方向上有强烈主特征值 λ₁ ≫ λ₂, λ₃… → Hilbert 项明显收缩
# >
# > 加大正则：
# > 光谱被“抹平” → λ₁ 和其余 λ_i 的差距变小 → projective 收缩减弱 → ratio 更接近 1。
#
# ---
#
# ## 如果你想验证这些直觉，可以试几个小实验：
#
# 1. **画不同 λ 下的 ratio 曲线，只看后半段（支撑稳定之后）**
#
#    * 拟合一条：
#      [
#      d_H(w_t, w^*) \approx C\cdot q^t
#      ]
#    * 比较不同 λ 下估计出来的 q(λ)；
#    * 我猜测 q(λ) 会随 λ 单调上升（→1）。
#
# 2. **在同样 n、同样 λ 下，画“有效维数 vs t”**
#
#    比如：
#
#    ```python
#    eff_dim_t = (w_t.abs() > threshold).sum().item()
#    ```
#
#    * 看小样本 vs 大样本；
#    * 看 λ 小 vs λ 大；
#    * 对比 eff_dim 稳定后，Hilbert 比率才开始趋于常数。
#
# 3. **看 w* 的光谱/condition vs λ**
#
#    虽然你现在是非线性模型，但你可以在 w* 附近做一个 Hessian 或 Fisher 近似，至少看一下“各方向 curvature”的 spread 有没有随 λ 变得更均匀 → 这会非常支持“PF gap 变小→收缩常数接近 1”的故事。
#
# ---
#
# 总的来说，你现在的三条“猜测”如果翻译成更严谨一点的版本，大概是：
#
# 1. 小样本：算子时间不齐次 + 噪声大 + 支撑未稳定 → Hilbert 轨迹高度非单调，很难直接读 PF 常数；
# 2. 大样本：维数收缩早期完成，且在 Hilbert 度量下对极小坐标不敏感 → 你只看到 small cone 内的几何收缩；
# 3. L2 大：降低过拟合的同时，也抹平了主方向 → projective contraction 常数变弱，Hilbert 比率更快升到 1。
#
# 如果你愿意，我们可以下一步专门设计一个“小玩具线性模型”，把这些现象在一个理论上完全可控的 setting 里验证一遍（比如固定 A 正矩阵 + 加一个 L2 项，把正则当成改变谱结构的 perturbation，看 Hilbert contraction 常数怎么变）。
