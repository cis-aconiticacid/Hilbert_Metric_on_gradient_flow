# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader
from matplotlib import pyplot as plt
import sys
import matplotlib.pyplot as plt
from pathlib import Path

# add repo root so swiss_roll_models can be imported from anywhere
for p in [Path.cwd(), *Path.cwd().parents]:
    if (p / "swiss_roll_models").exists():
        sys.path.insert(0, str(p))
        break

from functions.dataset import generate_swiss_roll
from functions.Hilbert_computation import hilbert_computation as hbc
import functions.graph_print_analysis as gp_tools
# positive linear model = softplus(theta) ∈ R^D_{>0}
class PositiveLinear(nn.Module):
    def __init__(self, D):
        super().__init__()
        self.theta = nn.Parameter(torch.zeros(D))  # trainable parameters
    def forward(self, X):
        w = F.softplus(self.theta)
        return X @ w

    def positive_params_vector(self):
        # Return the current positive parameter vector for Hilbert distance calculation
        return F.softplus(self.theta).detach().clone()

# %%
def run_experiment_on_subset(
    X_full : torch.Tensor,
    y_full : torch.Tensor,
    n: int,
    num_epochs : int = 500,
    lr : float = 1e-2,
    l2_reg : float = 1e-3,
    device : str = 'cuda',
    seed : int = 114514,
    batch_size : int = None,
) -> dict:
        
    """
    Run training on a random subset of size n from (X_full, y_full).
        Args:
            X_full: Full input data tensor of shape (N, D).
            y_full: Full target data tensor of shape (N,).
            n: Size of the subset to sample for training.
            num_epochs: Number of training epochs.
            lr: Learning rate for SGD.
            l2_reg: L2 regularization coefficient.
            device: Device to run the computations on ("cuda" or "cpu").

        Returns:
            A dictionary containing:
                - 'n': The subset size used.
                - 'loss_traj': List of loss values per epoch.
                - 'param_traj': List of parameter vectors per epoch.
                - 'w_star': Final learned positive parameter vector.
    """
    if batch_size is None:
        batch_size = n  # full-batch
    torch.manual_seed(seed)
    N, D = X_full.shape
    idx = torch.randperm(N, device=device)[:n]
    X = X_full[idx]
    y = y_full[idx]
    dataset = TensorDataset(X, y)
    loader = DataLoader(dataset, batch_size=batch_size, shuffle=True)  # full-batch

    model = PositiveLinear(D).to(device)
    optimizer = torch.optim.SGD(model.parameters(), lr=lr)

    param_traj = []
    loss_traj = []
    mse_traj = []
    l2_traj = []
    theta_traj = []

    for epoch in range(num_epochs):
        for batch_X, batch_y in loader:
            optimizer.zero_grad()

            # 1. prediction
            y_pred = model(batch_X)

            # 2. MSE part
            mse = F.mse_loss(y_pred, batch_y)

            # 3. L2 regularization: regularize w = softplus(theta) in the positive cone
            w = F.softplus(model.theta)
            l2 = (w ** 2).sum()

            # 4. Total loss = mse + λ ||w||^2
            loss = mse + l2_reg * l2

            loss.backward()
            optimizer.step()
        with torch.no_grad():
            theta_t=model.theta.detach().cpu().clone()
            w_t=model.positive_params_vector().cpu().clone()
        loss_traj.append(loss.item())
        mse_traj.append(mse.item())
        l2_traj.append(l2.item())
        param_traj.append(w_t)
        theta_traj.append(theta_t)


    w_star = param_traj[-1]

    prev = param_traj[0]
    return {
        "n": n,
        "num_epochs": num_epochs,
        "lr": lr,
        "l2_reg": l2_reg,
        "seed": seed,
        "loss_traj": loss_traj,
        "mse_traj": mse_traj,
        "l2_traj": l2_traj,
        "param_traj": param_traj,   # list length = num_epochs+1
        "theta_traj": theta_traj,   # optional, to observe inside/outside the cone
        "w_star": w_star,
    }

# %%
from matplotlib.ticker import MaxNLocator


device = "cuda" if torch.cuda.is_available() else "cpu"
print("Using device:", device)

# ----- Generate Swiss roll -----
N = 50_000
D = 280
X_full, y_full, u, v = generate_swiss_roll(
    n_samples=N,
    D=D,
    noise=53,
    device=device,
)
print(f"Full dataset: X={X_full.shape}, y={y_full.shape}")

# ----- Different small sample sizes -----
n_list = [50, 100, 200, 500]
num_epochs = 150
lr = 1e-3
l2_list = [0,1e-3,1e-2,1e-1]
l2 = l2_list[2]
first_20s=[]
other_20s=[]
# all_results[n][l2_reg] = corresponding experiment results
all_results = {}
n=9128
names=[]
# Out:
# Using device: cuda
# Full dataset: X=torch.Size([50000, 280]), y=torch.Size([50000])

# %%
for n in n_list:
    print(f"\n================ n = {n} ================")
    title = f"n={n} and l2_reg={l2}"
    print(f"\n--- Running experiment as {title} ---")
    res = run_experiment_on_subset(
        X_full,
        y_full,
        n=n,
        # num_epochs=num_epochs,
        lr=lr,
        l2_reg= l2,
        device=device,
        seed=27189045,
    )
    names.append(title)
    all_results[title] = res  
    w = res['w_star']
    trajectory = res['param_traj']
    first_20_param = trajectory[:20]
    w_20 = trajectory[20]
    other_20_param = trajectory[20:-1]
    hdist_traj=hbc.compute_hilbert_to_w_star(trajectory=first_20_param, w_star=w_20)
    hdist_traj2=hbc.compute_hilbert_to_w_star(trajectory=other_20_param, w_star=trajectory[-1])
    first_20 = hdist_traj
    other_20 = hdist_traj2
    first_20s.append(first_20)
    other_20s.append(other_20)
# Out:
# ================ n = 50 ================
#
# --- Running experiment as n=50 and l2_reg=0.01 ---
#
# ================ n = 100 ================
#
# --- Running experiment as n=100 and l2_reg=0.01 ---
#
# ================ n = 200 ================
#
# --- Running experiment as n=200 and l2_reg=0.01 ---
#
# ================ n = 500 ================
#
# --- Running experiment as n=500 and l2_reg=0.01 ---

# %%
fig = plt.figure(figsize=(8, 6))
y_min = 0
y_max = max(
    max(max(group) for group in first_20s),
    max(max(group) for group in other_20s)
) * 1.1
print(len(first_20s))
import matplotlib.cm as cm
plt.figure(figsize=(8, 6)) 
plt.ylim(y_min, y_max)
plt.xscale('linear')
plt.yscale('linear')
plt.gca().xaxis.set_major_locator(MaxNLocator(integer=True))
num_groups = len(first_20s)

start, end = 0.3, 1.0
colors = cm.Blues([start + (end - start) * i / (num_groups - 1) for i in range(num_groups)])
for i, first_20 in enumerate(first_20s):
    first_20
    plt.plot(range(len(first_20)), first_20, marker='o', color=colors[i],label=names[i])

plt.legend()
plt.show()


plt.figure(figsize=(8, 6))
plt.ylim(y_min, y_max)
plt.xscale('linear')
plt.yscale('linear')
plt.gca().xaxis.set_major_locator(MaxNLocator(integer=True))
for i, other_20 in enumerate(other_20s):
    plt.plot(range(len(other_20)), other_20, marker='o', color=colors[i],label=names[i])
plt.legend()
plt.show()
# Out:
# 4

# %%
import numpy as np
print(all_results.keys())
res=all_results[names[0]]
# Out:
# dict_keys(['n=50 and l2_reg=0.01', 'n=100 and l2_reg=0.01', 'n=200 and l2_reg=0.01', 'n=500 and l2_reg=0.01'])

# %%
hilbert_to_final=hbc.compute_hilbert_to_w_star(res['param_traj'],res['w_star'],)
l2_to_final=np.linalg.norm(np.array(res['param_traj'])-res['w_star'].cpu().numpy(),axis=1)
cos_to_final=res['param_traj']@res['w_star'].cpu().numpy()/(np.linalg.norm(np.array(res['param_traj']),axis=1)*np.linalg.norm(res['w_star'].cpu().numpy()))
loss_traj=res['loss_traj']
print(first_20s[2])
# Out:
# [0.052065631241245136, 0.01915860399385038, 0.010020577690891798, 0.005858027854117337, 0.0036391164557552807, 0.0022418029702760025, 0.0013800089202744767, 0.0008413385268396447, 0.0005176890986720799, 0.00031247337968315516, 0.00019412287558448862, 0.00011477344058478412, 7.375304687278554e-05, 4.1196805628637955e-05, 2.8820779654588162e-05, 1.3798360276349141e-05, 1.2027599863296065e-05, 3.7486780637724415e-06, 5.936951226790216e-06, 0.0]

# %%
plt.plot(hilbert_to_final[1:50],label='Hilbert distance to final',)
plt.plot(l2_to_final[1:50],label='L2 distance to final')
plt.plot(cos_to_final[1:50],label='Cosine similarity to final')
plt.legend()
plt.show()
plt.plot(loss_traj,label='Loss trajectory')

# %%
h = np.array(hilbert_to_final)
h_even = h[0::2]
h_odd  = h[1::2]

ratio_even = h_even[1:] / h_even[:-1]   # 每两步之间的收缩比例，真正对应 |λ|^2
ratio_odd  = h_odd[1:] / h_odd[:-1]
plt.plot(ratio_even,label='Even step ratio')
plt.plot(ratio_odd,label='Odd step ratio')

# %%
from sklearn.decomposition import PCA
trajectory = res['param_traj']
w_traj = np.array(trajectory[1:20])    # shape: (T+1, D)
w_star = res['w_star'].cpu().numpy()  # shape: (D,
R = w_traj - w_star          # shape: (T+1, D)
pca = PCA(n_components=1)
pca.fit(R)
v = pca.components_[0]       # 主方向，单位向量

a = R @ v                    # shape: (T+1,)
print('first 20 largest eigenvalue',a)
numpy_hilbert_to_final20=np.array(hilbert_to_final[:20])
print('hilbert to final first 20 steps',numpy_hilbert_to_final20)
# Out:
# first 20 largest eigenvalue [-5.78921847e-02  3.61191928e-02 -2.21367851e-02  1.47628365e-02
#  -8.94099288e-03  6.39747083e-03 -3.57481092e-03  2.92155659e-03
#  -1.31841935e-03  1.44888030e-03 -3.60096252e-04  8.20620917e-04
#   4.80041490e-05  5.51587669e-04  2.21225084e-04  4.36002389e-04
#   2.94399943e-04  3.85753519e-04  3.24895285e-04]
# hilbert to final first 20 steps [5.76136773e-02 2.69950510e-02 1.73200000e-02 1.12807375e-02
#  7.34004042e-03 4.79198485e-03 3.12639534e-03 2.04310961e-03
#  1.33417998e-03 8.72151385e-04 5.69718942e-04 3.72493941e-04
#  2.43406916e-04 1.59073109e-04 1.04325574e-04 6.83989897e-05
#  4.53798919e-05 3.22981695e-05 2.07852074e-05 1.73981545e-05]

# %%
hilbert_to_betwee=hbc.compute_hilbert_between_steps(res['param_traj'])
vector_hilbert_between_steps=np.array(hilbert_to_betwee)
print(vector_hilbert_between_steps[:20])
ratio_to_between=vector_hilbert_between_steps[1:20]/vector_hilbert_between_steps[0:19]
# Out:
# [8.42137082e-02 4.38614491e-02 2.86007375e-02 1.86207779e-02
#  1.21320253e-02 7.91838019e-03 5.16950495e-03 3.37728959e-03
#  2.20633136e-03 1.44187033e-03 9.42212883e-04 6.15900856e-04
#  4.02480024e-04 2.62936378e-04 1.71893706e-04 1.12377502e-04
#  7.34492154e-05 4.78995229e-05 3.12699601e-05 2.05014869e-05]

# %% [raw]
# Using device: cuda
# Full dataset: X=torch.Size([10000, 32]), y=torch.Size([10000])
#
# ================ n = 50 ================
#
# --- Running experiment (n=50, l2_reg=0.0) ---
# Final loss: 0.000417
# Initial d_H(w_t, w*): 0.897720
# Final   d_H(w_t, w*): 0.000000
# First 15 ratio d_H(w_t, w*)/d_H(w_{t-1}, w*): [0.7309296271847966, 0.7447428889929681, 0.7411222350197112, 0.741969291039624, 0.7434974677038807, 0.7448942832888344, 0.7460374587830831, 0.7469546109889609, 0.7476819867678656, 0.7482619127808903, 0.7487204167120306, 0.7490829677465016, 0.749366709513537, 0.7495950488501278, 0.7497753303591459]
# First 15 ratio d_H(w_t, w*)/d_H(w_0, w*): [1.0, 0.7309296271847966, 0.5443546422001585, 0.40343332907073665, 0.29933514115236975, 0.22255491944157063, 0.16577988720983303, 0.12367800577136999, 0.09238185668884412, 0.0690722501504192, 0.05168413401763281, 0.03869696635908247, 0.028987238403048034, 0.021722071459976542, 0.016282757217167085]
# First 15 d_H(w_t, w*): [0.8977199792861938, 0.656170129776001, 0.4886780381202698, 0.36217015981674194, 0.2687191367149353, 0.19979199767112732, 0.14882391691207886, 0.11102821677923203, 0.08293303847312927, 0.062007538974285126, 0.04639787971973419, 0.034739039838314056, 0.026022423058748245, 0.019500337541103363, 0.014617356471717358]
# First 15 d_H(w_t, w_0): [0.0, 0.32655203342437744, 0.4902617037296295, 0.5893856287002563, 0.6635526418685913, 0.7198432683944702, 0.7606230974197388, 0.7956521511077881, 0.8215872049331665, 0.8408515453338623, 0.8551958799362183, 0.8658961057662964, 0.8738889098167419, 0.8798658847808838, 0.8843388557434082]
# First 15 d_H(w_{t+1}, w_t): [0.32655203342437744, 0.17794421315193176, 0.12650781869888306, 0.09345106035470963, 0.06892714649438858, 0.05096820369362831, 0.0377955287694931, 0.028095178306102753, 0.020925551652908325, 0.015609702095389366, 0.011658895760774612, 0.008716541342437267, 0.0065220994874835014, 0.004882933106273413, 0.003657620633020997]
#
# --- Running experiment (n=50, l2_reg=0.0001) ---
# Final loss: 0.002042
# Initial d_H(w_t, w*): 0.847441
# Final   d_H(w_t, w*): 0.000000
# First 15 ratio d_H(w_t, w*)/d_H(w_{t-1}, w*): [0.7442883690251144, 0.7492005343379007, 0.7499348203747913, 0.7509617905084163, 0.7520309047361162, 0.752979934281479, 0.7537812174590246, 0.754455590101649, 0.7550252315682972, 0.7555065209376296, 0.7559133745241216, 0.756260806747927, 0.7565669850503902, 0.7568279351360037, 0.7570647126315163]
# First 15 ratio d_H(w_t, w*)/d_H(w_0, w*): [1.0, 0.7442883690251144, 0.5576212437751004, 0.4181795872876476, 0.3140368916236024, 0.23616544772821538, 0.1778278433099477, 0.13404328822828504, 0.10112970811943621, 0.07635548129131163, 0.05768706402491711, 0.04360642323346415, 0.032977828813931145, 0.02494993651926377, 0.018882808937648772]
# First 15 d_H(w_t, w*): [0.8474408984184265, 0.6307404041290283, 0.47255104780197144, 0.3543824851512909, 0.26612770557403564, 0.20013625919818878, 0.15069858729839325, 0.11359376460313797, 0.08570145070552826, 0.06470675766468048, 0.04888637736439705, 0.036953866481781006, 0.02794676087796688, 0.0211435966193676, 0.01600206457078457]
# First 15 d_H(w_t, w_0): [0.0, 0.3108658790588379, 0.4655780792236328, 0.5587974786758423, 0.6243318915367126, 0.6808757781982422, 0.7225872278213501, 0.7535954117774963, 0.7767635583877563, 0.7941349744796753, 0.8071932196617126, 0.8170276880264282, 0.8244445323944092, 0.8300439715385437, 0.8342745900154114]
# First 15 d_H(w_{t+1}, w_t): [0.3108658790588379, 0.16278895735740662, 0.11816868185997009, 0.0882546603679657, 0.06599153578281403, 0.04943770915269852, 0.03710481524467468, 0.027892280369997025, 0.020994797348976135, 0.01582040823996067, 0.011932481080293655, 0.009007217362523079, 0.006803254596889019, 0.005141472443938255, 0.0038874177262187004]
#
# --- Running experiment (n=50, l2_reg=0.001) ---
# Final loss: 0.014731
# Initial d_H(w_t, w*): 0.351660
# Final   d_H(w_t, w*): 0.000000
# First 15 ratio d_H(w_t, w*)/d_H(w_{t-1}, w*): [0.6364427058756529, 0.6704518898552183, 0.6546610074815286, 0.6497225532834064, 0.6486709290014253, 0.6490408407935004, 0.6500196860218155, 0.651474871330257, 0.6535374581594359, 0.6565130730830816, 0.6609147774321543, 0.667328519972815, 0.676713847406101, 0.6900969630607895, 0.7085339269817125]
# First 15 ratio d_H(w_t, w*)/d_H(w_0, w*): [1.0, 0.6364427058756529, 0.4267042149389004, 0.27934661124851523, 0.18149779351145245, 0.11773234232878273, 0.07641309845366137, 0.04967001826480303, 0.032358768758034076, 0.021147667483294552, 0.013883720167996865, 0.009175955824761961, 0.00612337701987433, 0.004143774022237262, 0.002859605868356127]
# First 15 d_H(w_t, w*): [0.35165977478027344, 0.2238112986087799, 0.1500547081232071, 0.09823496639728546, 0.06382547318935394, 0.04140172898769379, 0.026871412992477417, 0.017466947436332703, 0.01137927733361721, 0.007436783984303474, 0.004882345907390118, 0.0032268145587295294, 0.0021533453837037086, 0.0014571986394003034, 0.0010056083556264639]
# First 15 d_H(w_t, w_0): [0.0, 0.14915089309215546, 0.2268492579460144, 0.2731490433216095, 0.301522433757782, 0.31939858198165894, 0.3308113217353821, 0.338143914937973, 0.34286990761756897, 0.34592151641845703, 0.3478938937187195, 0.3491699695587158, 0.3499956429004669, 0.35053035616874695, 0.3508766293525696]
# First 15 d_H(w_{t+1}, w_t): [0.14915089309215546, 0.0802392065525055, 0.05181971564888954, 0.03440943360328674, 0.022423751652240753, 0.014530310407280922, 0.00940454937517643, 0.006087671034038067, 0.003942481707781553, 0.002554332371801138, 0.0016556668560951948, 0.0010732783703133464, 0.0006963176419958472, 0.00045163172762840986, 0.0002931391354650259]
#
# --- Running experiment (n=50, l2_reg=0.01) ---
# Final loss: 0.149029
# Initial d_H(w_t, w*): 0.869638
# Final   d_H(w_t, w*): 0.000000
# First 15 ratio d_H(w_t, w*)/d_H(w_{t-1}, w*): [0.68607972303434, 0.7056536076995159, 0.7143944814940473, 0.7199652350990546, 0.72363722716726, 0.7259841420509515, 0.7273956019831995, 0.7280961406004511, 0.7282003717457868, 0.7277480794080979, 0.7266818690136384, 0.7248972974378908, 0.7221740491126514, 0.7563456268064205, 0.8116542305377099]
# First 15 ratio d_H(w_t, w*)/d_H(w_0, w*): [1.0, 0.68607972303434, 0.48413463172866666, 0.34586310920711233, 0.24900941473238863, 0.18019248241548796, 0.1308168847504392, 0.09515562663261255, 0.06928244450762269, 0.050451501845907694, 0.03671598357161343, 0.02668083956449409, 0.019340868493675716, 0.013967473313433098, 0.010564237358150506]
# First 15 d_H(w_t, w*): [0.8696384429931641, 0.5966413021087646, 0.42102208733558655, 0.3007758557796478, 0.2165481597185135, 0.15670230984687805, 0.11376339197158813, 0.08275099098682404, 0.06025067716836929, 0.04387456551194191, 0.031929630786180496, 0.02320268377661705, 0.016819562762975693, 0.01214665174484253, 0.009187066927552223]
# First 15 d_H(w_t, w_0): [0.0, 0.30149343609809875, 0.46917545795440674, 0.5795953869819641, 0.6553057432174683, 0.7129361629486084, 0.7558749914169312, 0.7868874669075012, 0.8093878030776978, 0.8257638812065125, 0.8377088904380798, 0.8464357852935791, 0.8528189659118652, 0.8574919104576111, 0.8609146475791931]
# First 15 d_H(w_{t+1}, w_t): [0.30149343609809875, 0.17561912536621094, 0.12024641036987305, 0.08422766625881195, 0.059845831245183945, 0.042938847094774246, 0.031012464314699173, 0.02250033989548683, 0.016375992447137833, 0.011945031583309174, 0.008726845495402813, 0.006383238360285759, 0.004672801122069359, 0.0034228223375976086, 0.002508268691599369]
#
# ================ n = 100 ================
#
# --- Running experiment (n=100, l2_reg=0.0) ---
# Final loss: 0.000528
# Initial d_H(w_t, w*): 0.823365
# Final   d_H(w_t, w*): 0.000000
# First 15 ratio d_H(w_t, w*)/d_H(w_{t-1}, w*): [0.6379325247492069, 0.6808103758208595, 0.690781744939058, 0.6970675707777508, 0.7013199246627669, 0.7042493757486944, 0.7062984805634456, 0.7077393786483056, 0.7087634372137278, 0.709483669584438, 0.7100000487933917, 0.7103578570424899, 0.7106434636951421, 0.7108069304030337, 0.7109505857454889]
# First 15 ratio d_H(w_t, w*)/d_H(w_0, w*): [1.0, 0.6379325247492069, 0.4343110819228573, 0.30001416701704153, 0.20913014660147958, 0.14666713865926304, 0.1032902408436332, 0.07295374016489047, 0.051632234734369516, 0.03659504016135776, 0.02596358338226999, 0.018434145468262986, 0.01309484007124482, 0.009305762504763362, 0.006614600481070491]
# First 15 d_H(w_t, w*): [0.8233652114868164, 0.5252514481544495, 0.35759663581848145, 0.24702122807502747, 0.17219048738479614, 0.12076061964035034, 0.08504559099674225, 0.06006757169961929, 0.042512185871601105, 0.030131082981824875, 0.02137751132249832, 0.015178034082055092, 0.01078183576464653, 0.007662041112780571, 0.005446231923997402]
# First 15 d_H(w_t, w_0): [0.0, 0.29811379313468933, 0.4657685160636902, 0.5763438940048218, 0.6511747241020203, 0.7026045322418213, 0.7383196949958801, 0.7632975578308105, 0.7808530330657959, 0.7932342290878296, 0.8019877076148987, 0.8081872463226318, 0.812583327293396, 0.8157032132148743, 0.8179189562797546]
# First 15 d_H(w_{t+1}, w_t): [0.29811379313468933, 0.16765469312667847, 0.11057548224925995, 0.07483077049255371, 0.05142993852496147, 0.035715050995349884, 0.02497800439596176, 0.01755540445446968, 0.012381158769130707, 0.008753446862101555, 0.0061994632706046104, 0.004396140109747648, 0.003119847271591425, 0.0022157798521220684, 0.0015743544790893793]
#
# --- Running experiment (n=100, l2_reg=0.0001) ---
# Final loss: 0.001967
# Initial d_H(w_t, w*): 0.974515
# Final   d_H(w_t, w*): 0.000000
# First 15 ratio d_H(w_t, w*)/d_H(w_{t-1}, w*): [0.7408515733861328, 0.7344290576023859, 0.7390395427640276, 0.7437873160691304, 0.7474435911095478, 0.7501873474851934, 0.7522607378895294, 0.753840612949082, 0.7550502115010457, 0.7559798245502894, 0.7567002271306402, 0.7572549984523935, 0.7576960025089776, 0.7580511613965953, 0.7583406694873015]
# First 15 ratio d_H(w_t, w*)/d_H(w_0, w*): [1.0, 0.7408515733861328, 0.5441029228652223, 0.40211357533088493, 0.299086976950321, 0.22355064410584646, 0.16770486473037147, 0.12615778528973295, 0.09510286219111097, 0.07180743621175313, 0.05428497302876724, 0.04107745142064884, 0.031106105411971712, 0.02356897172427384, 0.017866486388509302]
# First 15 d_H(w_t, w*): [0.9745146036148071, 0.7219706773757935, 0.5302362442016602, 0.3918655514717102, 0.291464626789093, 0.2178533673286438, 0.1634308397769928, 0.12294260412454605, 0.09267912805080414, 0.06997739523649216, 0.0529014989733696, 0.040030576288700104, 0.03031335398554802, 0.02296830713748932, 0.01741115190088749]
# First 15 d_H(w_t, w_0): [0.0, 0.3143501281738281, 0.4823819398880005, 0.609411358833313, 0.7041146755218506, 0.7731382250785828, 0.8239161968231201, 0.861523449420929, 0.8895213603973389, 0.91045081615448, 0.9261481761932373, 0.9379521012306213, 0.946846604347229, 0.9535597562789917, 0.9586327075958252]
# First 15 d_H(w_{t+1}, w_t): [0.3143501281738281, 0.19173452258110046, 0.13837069272994995, 0.10040105134248734, 0.07361117005348206, 0.054422527551651, 0.040488213300704956, 0.03026347979903221, 0.022701729089021683, 0.017075881361961365, 0.012870915234088898, 0.009717084467411041, 0.007345177233219147, 0.005557015538215637, 0.004207700490951538]
#
# --- Running experiment (n=100, l2_reg=0.001) ---
# Final loss: 0.015623
# Initial d_H(w_t, w*): 0.661852
# Final   d_H(w_t, w*): 0.000000
# First 15 ratio d_H(w_t, w*)/d_H(w_{t-1}, w*): [0.6713255715937623, 0.6735085974426468, 0.6790442216299979, 0.6841110129786171, 0.687894114232082, 0.6905811421517465, 0.6931257433523904, 0.6945849664111852, 0.6950884257022683, 0.6953280145079409, 0.6953539477861421, 0.6951798471731353, 0.6958437041634802, 0.6963772813167953, 0.6964674516141698]
# First 15 ratio d_H(w_t, w*)/d_H(w_0, w*): [1.0, 0.6713255715937623, 0.452143544151498, 0.30702546100338257, 0.21003949913725095, 0.1444849352127694, 0.09977857158295539, 0.06915909659907565, 0.04803686878829687, 0.0333898715017237, 0.02321691305596882, 0.016143972148875543, 0.011222964091222655, 0.007809428904930097, 0.005438308869452019]
# First 15 d_H(w_t, w*): [0.6618523597717285, 0.44431841373443604, 0.2992522716522217, 0.20320552587509155, 0.13901513814926147, 0.09562769532203674, 0.06603868305683136, 0.045773111283779144, 0.03179331496357918, 0.022099165245890617, 0.015366168692708015, 0.010684926062822342, 0.007427945267409086, 0.005168688949197531, 0.00359935755841434]
# First 15 d_H(w_t, w_0): [0.0, 0.2280578315258026, 0.36767464876174927, 0.4586469531059265, 0.522837221622467, 0.5662245750427246, 0.5958137512207031, 0.6161229014396667, 0.6301257610321045, 0.6398112773895264, 0.6465259790420532, 0.6511882543563843, 0.6544291973114014, 0.6566838026046753, 0.6582530736923218]
# First 15 d_H(w_{t+1}, w_t): [0.2280578315258026, 0.1450660079717636, 0.0960468053817749, 0.06419025361537933, 0.043387480080127716, 0.029589181765913963, 0.020309191197156906, 0.014002805575728416, 0.009694203734397888, 0.0067329369485378265, 0.004681190941482782, 0.0032570315524935722, 0.002267456380650401, 0.0015787715092301369, 0.0010997203644365072]
#
# --- Running experiment (n=100, l2_reg=0.01) ---
# Final loss: 0.146458
# Initial d_H(w_t, w*): 0.631633
# Final   d_H(w_t, w*): 0.000000
# First 15 ratio d_H(w_t, w*)/d_H(w_{t-1}, w*): [0.6711670739029886, 0.676166785122009, 0.6811516505434371, 0.6859528667529314, 0.6890360961205864, 0.6901192695436787, 0.6904349052922002, 0.6900842977108251, 0.689049350881492, 0.6871939617902894, 0.6857906333031197, 0.7078948547371, 0.7614223892768851, 0.7871318917444081, 0.8906822451933808]
# First 15 ratio d_H(w_t, w*)/d_H(w_0, w*): [1.0, 0.6711670739029886, 0.4538208826407296, 0.30912084326181244, 0.21204232860852384, 0.14610481831673577, 0.1008297504935576, 0.06961637923265561, 0.04804117017193762, 0.03310273712256091, 0.022748001069355116, 0.01560036605973309, 0.01104341886570034, 0.008408706378506981, 0.006618760958837472]
# First 15 d_H(w_t, w*): [0.6316328644752502, 0.42393118143081665, 0.2866481840610504, 0.19525088369846344, 0.1339329034090042, 0.09228460490703583, 0.06368738412857056, 0.043971993029117584, 0.03034438192844391, 0.02090877667069435, 0.014368385076522827, 0.009853703901171684, 0.006975386291742325, 0.005311215296387672, 0.004180626943707466]
# First 15 d_H(w_t, w_0): [0.0, 0.27143755555152893, 0.3877031207084656, 0.4590602517127991, 0.5092812776565552, 0.5470536947250366, 0.5735424160957336, 0.5917388200759888, 0.6042793989181519, 0.6129446625709534, 0.6189422607421875, 0.6230982542037964, 0.6259804964065552, 0.6279799938201904, 0.6293679475784302]
# First 15 d_H(w_{t+1}, w_t): [0.27143755555152893, 0.13728591799736023, 0.09139734506607056, 0.06145143508911133, 0.04180377721786499, 0.028648406267166138, 0.01972450315952301, 0.013627600856125355, 0.009435582906007767, 0.006540490314364433, 0.004536965861916542, 0.0031489033717662096, 0.002186094643548131, 0.0015181145863607526, 0.001054177526384592]
#
# ================ n = 200 ================
#
# --- Running experiment (n=200, l2_reg=0.0) ---
# Final loss: 0.000436
# Initial d_H(w_t, w*): 0.700592
# Final   d_H(w_t, w*): 0.000000
# First 15 ratio d_H(w_t, w*)/d_H(w_{t-1}, w*): [0.6752160501127022, 0.6955907404794065, 0.6939712622420044, 0.6953900285753626, 0.6976592907116719, 0.699761424892085, 0.7014106235843716, 0.702612571370004, 0.7034622486303822, 0.7040619891221571, 0.7044716972551209, 0.7047555395544826, 0.7049481734918087, 0.7050849724380648, 0.7051496728668734]
# First 15 ratio d_H(w_t, w*)/d_H(w_0, w*): [1.0, 0.6752160501127022, 0.46967403228147453, 0.3259402810246669, 0.2266556213356048, 0.1581284000168113, 0.11065215451166949, 0.07761259669698432, 0.054531586135971234, 0.0383609122045917, 0.02700846015130527, 0.01902669576303732, 0.013409169238418355, 0.009452769362665567, 0.006665005625538434]
# First 15 d_H(w_t, w*): [0.7005921602249146, 0.4730510711669922, 0.3290499448776245, 0.22835120558738708, 0.1587931513786316, 0.11078351736068726, 0.07752203196287155, 0.054374776780605316, 0.03820440173149109, 0.02687535434961319, 0.01892191544175148, 0.013329953886568546, 0.009394358843564987, 0.0066225361078977585, 0.00466945068910718]
# First 15 d_H(w_t, w_0): [0.0, 0.2711755931377411, 0.4107636511325836, 0.4952911138534546, 0.5558222532272339, 0.600034236907959, 0.6303960084915161, 0.651427149772644, 0.6660800576210022, 0.6763290166854858, 0.6835165023803711, 0.6885661482810974, 0.6921184062957764, 0.6946195363998413, 0.6963813304901123]
# First 15 d_H(w_{t+1}, w_t): [0.2711755931377411, 0.15126661956310272, 0.10069870948791504, 0.06955808401107788, 0.04800967127084732, 0.03326135873794556, 0.02314715087413788, 0.016170313581824303, 0.011329002678394318, 0.007953537628054619, 0.005591969937086105, 0.003935528453439474, 0.0027718585915863514, 0.001953007304109633, 0.001376808388158679]
#
# --- Running experiment (n=200, l2_reg=0.0001) ---
# Final loss: 0.002018
# Initial d_H(w_t, w*): 0.753551
# Final   d_H(w_t, w*): 0.000000
# First 15 ratio d_H(w_t, w*)/d_H(w_{t-1}, w*): [0.5766498224003799, 0.6698408909939735, 0.6913543235140113, 0.6910694905856204, 0.6923366399100264, 0.6936098953142121, 0.694597496864945, 0.695308393466948, 0.6958206846494548, 0.6961732825138355, 0.6964385051092244, 0.6966373828524748, 0.6967562534352741, 0.696900667520862, 0.6970395808915366]
# First 15 ratio d_H(w_t, w*)/d_H(w_0, w*): [1.0, 0.5766498224003799, 0.38626363082818704, 0.267045031189287, 0.1845466736674017, 0.12776842395346102, 0.08862144316282199, 0.06155623258945514, 0.04280056518965184, 0.029781518573647168, 0.020733097543662708, 0.01443932745959219, 0.010058975291600178, 0.007008653937573334, 0.0048843356075175745]
# First 15 d_H(w_t, w*): [0.75355064868927, 0.43453484773635864, 0.2910692095756531, 0.2012319564819336, 0.13906526565551758, 0.09627997875213623, 0.06678074598312378, 0.046385738998651505, 0.032252393662929535, 0.022441882640123367, 0.015623439103364944, 0.010880764573812485, 0.007579947356134653, 0.0052813757210969925, 0.003680594265460968]
# First 15 d_H(w_t, w_0): [0.0, 0.35719770193099976, 0.49201101064682007, 0.5804013609886169, 0.6361901760101318, 0.6731049418449402, 0.6980739235877991, 0.715155303478241, 0.7269164323806763, 0.735047459602356, 0.7406833171844482, 0.7445966601371765, 0.7473168969154358, 0.7492095232009888, 0.7505269050598145]
# First 15 d_H(w_{t+1}, w_t): [0.35719770193099976, 0.1549498289823532, 0.09312417358160019, 0.06216666102409363, 0.04278535395860672, 0.02949930913746357, 0.02039504237473011, 0.014133270829916, 0.009810637682676315, 0.006818419322371483, 0.004742691293358803, 0.003300915937870741, 0.0022986026015132666, 0.0016007787780836225, 0.0011150435311719775]
#
# --- Running experiment (n=200, l2_reg=0.001) ---
# Final loss: 0.015944
# Initial d_H(w_t, w*): 0.822961
# Final   d_H(w_t, w*): 0.000000
# First 15 ratio d_H(w_t, w*)/d_H(w_{t-1}, w*): [0.6983520734827954, 0.7037902797076748, 0.7080199757060189, 0.7121801070378845, 0.7157139604866357, 0.7184195482673646, 0.7203854508324546, 0.7217844812945884, 0.7227618468278654, 0.7234278933934053, 0.7238632175788262, 0.7241175774579397, 0.7242202590011054, 0.7241948101309501, 0.7240111953821128]
# First 15 ratio d_H(w_t, w*)/d_H(w_0, w*): [1.0, 0.6983520734827954, 0.4914934011308912, 0.3479871459283622, 0.24782952283506893, 0.17737504931380033, 0.12742970280192195, 0.09179850390240825, 0.066258735522819, 0.04788928605495174, 0.03464444532684792, 0.025077839665525868, 0.01815930450647922, 0.013151336212962321, 0.009524129431714537]
# First 15 d_H(w_t, w*): [0.8229605555534363, 0.5747162103652954, 0.4044796824455261, 0.28637969493865967, 0.20395392179489136, 0.14597266912460327, 0.10486961901187897, 0.07554654777050018, 0.05452832579612732, 0.039410993456840515, 0.028511011973023415, 0.02063807286322117, 0.014944391325116158, 0.010823030956089497, 0.007837982848286629]
# First 15 d_H(w_t, w_0): [0.0, 0.2809566557407379, 0.445444256067276, 0.5566604137420654, 0.6321930885314941, 0.68465256690979, 0.7216030359268188, 0.7478682994842529, 0.7684322595596313, 0.7835496664047241, 0.7944496870040894, 0.8023224472999573, 0.8080161809921265, 0.8121375441551208, 0.8151226043701172]
# First 15 d_H(w_{t+1}, w_t): [0.2809566557407379, 0.17023643851280212, 0.11810007691383362, 0.08242572844028473, 0.057981327176094055, 0.041103120893239975, 0.029322944581508636, 0.021018296480178833, 0.015117401257157326, 0.010900033637881279, 0.007872965186834335, 0.005693648010492325, 0.004121335223317146, 0.0029851305298507214, 0.002163116354495287]
#
# --- Running experiment (n=200, l2_reg=0.01) ---
# Final loss: 0.151620
# Initial d_H(w_t, w*): 1.021041
# Final   d_H(w_t, w*): 0.000000
# First 15 ratio d_H(w_t, w*)/d_H(w_{t-1}, w*): [0.7119274008156345, 0.7284924496163453, 0.7377311237451192, 0.7438202523194174, 0.7478788690569899, 0.7506088117043245, 0.7523975083561782, 0.7534521995297024, 0.7538920042540849, 0.7537579862618449, 0.7530418615387277, 0.7516768755498464, 0.7495387327939066, 0.7464250365284943, 0.7816089651126779]
# First 15 ratio d_H(w_t, w*)/d_H(w_0, w*): [1.0, 0.7119274008156345, 0.5186337361691794, 0.3826122489962184, 0.28459473958886694, 0.21284239198329036, 0.1597613749268836, 0.12020406042654444, 0.09056801372078117, 0.06827850138527118, 0.05146546570913859, 0.03875565010256728, 0.029131725979000853, 0.021835356974399627, 0.016298457127228955]
# First 15 d_H(w_t, w*): [1.021040678024292, 0.7269068360328674, 0.5295461416244507, 0.39066267013549805, 0.2905828058719635, 0.2173207402229309, 0.16312286257743835, 0.1227332353591919, 0.09247362613677979, 0.06971512734889984, 0.05254833400249481, 0.03957109525799751, 0.029744677245616913, 0.02229478769004345, 0.016641387715935707]
# First 15 d_H(w_t, w_0): [0.0, 0.30061763525009155, 0.49163907766342163, 0.6303780674934387, 0.7304578423500061, 0.8037199974060059, 0.8579177856445312, 0.8983075618743896, 0.9285671710968018, 0.951325535774231, 0.968492329120636, 0.9814695119857788, 0.9912959337234497, 0.9987459182739258, 1.004399299621582]
# First 15 d_H(w_{t+1}, w_t): [0.30061763525009155, 0.19736067950725555, 0.13888350129127502, 0.10007983446121216, 0.073262058198452, 0.05419774353504181, 0.04038981720805168, 0.030259624123573303, 0.022758517414331436, 0.01716677099466324, 0.01297726295888424, 0.009826326742768288, 0.00744997151196003, 0.005653484724462032, 0.004292978439480066]
#
# ================ n = 500 ================
#
# --- Running experiment (n=500, l2_reg=0.0) ---
# Final loss: 0.000454
# Initial d_H(w_t, w*): 0.737220
# Final   d_H(w_t, w*): 0.000000
# First 15 ratio d_H(w_t, w*)/d_H(w_{t-1}, w*): [0.6848785353039429, 0.7114741101137374, 0.7063729625295927, 0.7066821479124512, 0.7081470129630116, 0.7095437544657562, 0.7106348459502347, 0.7114437244962315, 0.7120449294858952, 0.7124751677429944, 0.7128090510706516, 0.7130463110084702, 0.7132169281443649, 0.7133515965714294, 0.7134548888775469]
# First 15 ratio d_H(w_t, w*)/d_H(w_0, w*): [1.0, 0.6848785353039429, 0.48727334644137266, 0.34419671728750095, 0.24323767547714592, 0.17224803332920727, 0.12221751626774843, 0.0868520258453517, 0.061790328747459974, 0.04399749027589542, 0.03134711926458935, 0.02234451033679048, 0.01593267066693908, 0.01136345043021012, 0.008106135506950687]
# First 15 d_H(w_t, w*): [0.737219512462616, 0.5049058198928833, 0.35922741889953613, 0.2537485361099243, 0.1793195605278015, 0.1269846111536026, 0.09010113775730133, 0.06402900815010071, 0.04555303603410721, 0.03243580833077431, 0.023109707981348038, 0.01647280901670456, 0.01174587570130825, 0.008377357386052608, 0.005976001266390085]
# First 15 d_H(w_t, w_0): [0.0, 0.3072047829627991, 0.45751357078552246, 0.5445497035980225, 0.6002706289291382, 0.6377813816070557, 0.6636474132537842, 0.6828163862228394, 0.6981871128082275, 0.7090758085250854, 0.7169786691665649, 0.7227954864501953, 0.7269361019134521, 0.7298858165740967, 0.7319883704185486]
# First 15 d_H(w_{t+1}, w_t): [0.3072047829627991, 0.15552125871181488, 0.10547879338264465, 0.07442903518676758, 0.05233480781316757, 0.03688350319862366, 0.026072153821587563, 0.01847582682967186, 0.013117305003106594, 0.009325980208814144, 0.006636991165578365, 0.004727023653686047, 0.0033685581292957067, 0.0024012899957597256, 0.0017123494762927294]
#
# --- Running experiment (n=500, l2_reg=0.0001) ---
# Final loss: 0.001956
# Initial d_H(w_t, w*): 0.769657
# Final   d_H(w_t, w*): 0.000000
# First 15 ratio d_H(w_t, w*)/d_H(w_{t-1}, w*): [0.6873626353201823, 0.6920593308954447, 0.6953721762403704, 0.7000779029987679, 0.703796130047163, 0.7064621255074892, 0.7083348291577901, 0.7096576167545252, 0.7105895201984301, 0.7112552120539524, 0.7117279554598661, 0.7120845469832164, 0.7123637027281329, 0.7125646468310592, 0.7127577090414312]
# First 15 ratio d_H(w_t, w*)/d_H(w_0, w*): [1.0, 0.6873626353201823, 0.4756957254822149, 0.33078557185680957, 0.23157566948776354, 0.16298205999856885, 0.11514065252617808, 0.08155813443624683, 0.057878351310972104, 0.04112774988793985, 0.02925232646784857, 0.020819698509406393, 0.014825385581397798, 0.010561066567136809, 0.0075254426685711475]
# First 15 d_H(w_t, w*): [0.7696573734283447, 0.5290337204933167, 0.3661227226257324, 0.25459155440330505, 0.17823392152786255, 0.1254403442144394, 0.08861885219812393, 0.06277181953191757, 0.044546499848365784, 0.031654275953769684, 0.02251426875591278, 0.016024034470319748, 0.011410467326641083, 0.008128402754664421, 0.0057920124381780624]
# First 15 d_H(w_t, w_0): [0.0, 0.2823987305164337, 0.4355505704879761, 0.5332686901092529, 0.6050137281417847, 0.6541398763656616, 0.6882119178771973, 0.712044358253479, 0.7288103103637695, 0.7406514883041382, 0.749037504196167, 0.7549877762794495, 0.7592153549194336, 0.7622217535972595, 0.7643612623214722]
# First 15 d_H(w_{t+1}, w_t): [0.2823987305164337, 0.1642986536026001, 0.11153115332126617, 0.07635747641324997, 0.05279367417097092, 0.03682155907154083, 0.02584698796272278, 0.018225276842713356, 0.012892249971628189, 0.009140034206211567, 0.006490330211818218, 0.004613427445292473, 0.0032821360509842634, 0.002336263656616211, 0.0016638328088447452]
#
# --- Running experiment (n=500, l2_reg=0.001) ---
# Final loss: 0.015898
# Initial d_H(w_t, w*): 0.706904
# Final   d_H(w_t, w*): 0.000000
# First 15 ratio d_H(w_t, w*)/d_H(w_{t-1}, w*): [0.6368956134111352, 0.6914781128702802, 0.6902832465582581, 0.6931015536114379, 0.6956539594723705, 0.697458198650222, 0.6986682399322857, 0.6994554125730629, 0.6999333763215692, 0.7001799803253661, 0.7002227181079669, 0.7000718514465579, 0.6997278377502893, 0.6991139967986637, 0.6981716675791874]
# First 15 ratio d_H(w_t, w*)/d_H(w_0, w*): [1.0, 0.6368956134111352, 0.44039937685689123, 0.3040003116390087, 0.21070308829535822, 0.14657643764572242, 0.10223093816495214, 0.07142550963433345, 0.04995895930952398, 0.03496794306702701, 0.024483853688689494, 0.017144150579651928, 0.012002137237775505, 0.008398229537770883, 0.005871319818183596]
# First 15 d_H(w_t, w*): [0.7069036960601807, 0.4502238631248474, 0.3113199472427368, 0.214898943901062, 0.14894679188728333, 0.1036154255270958, 0.07226742804050446, 0.050490956753492355, 0.03531617298722267, 0.02471896819770336, 0.01730772666633129, 0.012119263410568237, 0.008484355174005032, 0.0059367395006120205, 0.004150457680225372]
# First 15 d_H(w_t, w_0): [0.0, 0.31364738941192627, 0.45505625009536743, 0.5376505255699158, 0.5910043120384216, 0.6268175840377808, 0.6512739658355713, 0.6681337356567383, 0.6798244714736938, 0.6879613995552063, 0.6936393976211548, 0.6976079940795898, 0.700385332107544, 0.702330470085144, 0.7036936283111572]
# First 15 d_H(w_{t+1}, w_t): [0.31364738941192627, 0.1464834213256836, 0.09642088413238525, 0.06595207750797272, 0.045331522822380066, 0.03134789690375328, 0.02177659049630165, 0.015174771659076214, 0.010597139596939087, 0.007411337457597256, 0.005188461393117905, 0.0036349352449178696, 0.0025475709699094296, 0.0017862999811768532, 0.0012527175713330507]
#
# --- Running experiment (n=500, l2_reg=0.01) ---
# Final loss: 0.150146
# Initial d_H(w_t, w*): 0.847566
# Final   d_H(w_t, w*): 0.000000
# First 15 ratio d_H(w_t, w*)/d_H(w_{t-1}, w*): [0.6950219686665029, 0.7153551041619448, 0.7158298144275186, 0.7188639476435725, 0.7217365508245496, 0.7238726198217824, 0.7252748329569237, 0.7260406596813452, 0.7262466182301219, 0.7259006062869804, 0.7249759926407835, 0.7233416898208114, 0.740636526567455, 0.771017497031778, 0.7897749623875905]
# First 15 ratio d_H(w_t, w*)/d_H(w_0, w*): [1.0, 0.6950219686665029, 0.4971875127902661, 0.3559016450163357, 0.2558448615092844, 0.1846525878918955, 0.13366495255417835, 0.09694382613592682, 0.07038515947976196, 0.051116984045764924, 0.037105849710382666, 0.0269008502265644, 0.01945850646049965, 0.014411680637094845, 0.011111657932834208]
# First 15 d_H(w_t, w*): [0.8475660085678101, 0.5890769958496094, 0.42139923572540283, 0.30165013670921326, 0.21684540808200836, 0.1565052568912506, 0.11328987032175064, 0.08216629177331924, 0.05965606868267059, 0.043325018137693405, 0.031449656933546066, 0.022800246253609657, 0.016492368653416634, 0.012214850634336472, 0.009417863562703133]
# First 15 d_H(w_t, w_0): [0.0, 0.31889909505844116, 0.4813091456890106, 0.5793502330780029, 0.6473232507705688, 0.7022048234939575, 0.7426183223724365, 0.7715868353843689, 0.792473316192627, 0.8075944185256958, 0.8185738325119019, 0.8265625238418579, 0.8323841094970703, 0.8366310000419617, 0.8397313952445984]
# First 15 d_H(w_{t+1}, w_t): [0.31889909505844116, 0.17570939660072327, 0.11974911391735077, 0.08480469882488251, 0.06034015864133835, 0.043215446174144745, 0.031123699620366096, 0.02251010574400425, 0.016331082209944725, 0.01187526248395443, 0.008649437688291073, 0.006307809613645077, 0.0046041663736104965, 0.003362703137099743, 0.002457023598253727]
