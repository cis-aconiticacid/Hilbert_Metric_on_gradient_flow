# %%
process_all_models(
    ModelClass=MNISTNet,
    analysis_fn=gpa.analysis,
    device="cuda",
)
# Out:
# Found 178 .pt files in ./model_result/
#
# === Processing model_bs1024_lr0.01_steps2000.pt ===
#   batch_size = 1024, lr = 0.01, total_steps = 2000
#   Missing checkpoint while building param_traj: Checkpoint not found: ./model_result/model_bs1024_lr0.01_steps1.pt
#   -> Skip this run.
#
# === Processing model_bs2048_lr0.01_steps2000.pt ===
#   batch_size = 2048, lr = 0.01, total_steps = 2000
#   Missing checkpoint while building param_traj: Checkpoint not found: ./model_result/model_bs2048_lr0.01_steps1.pt
#   -> Skip this run.
#
# === Processing model_bs256_lr0.01_steps2000.pt ===
#   batch_size = 256, lr = 0.01, total_steps = 2000
#   Missing checkpoint while building param_traj: Checkpoint not found: ./model_result/model_bs256_lr0.01_steps1.pt
#   -> Skip this run.
#
# === Processing model_bs32_lr0.01_steps2000.pt ===
#   batch_size = 32, lr = 0.01, total_steps = 2000
# ...
